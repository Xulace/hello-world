# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
import pandas as pd
import sqlalchemy
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # SQL Miniproject

# %% [markdown]
# ## Introduction

# %% [markdown]
# The city of New York does restaurant inspections and assigns a grade. Inspections data for the last 4 years are available on s3 as an SQLite database, which you can import in the next few cells. These were extracted from a set of csv files and an XLS file, as described in the <b>How we loaded the data</b> section
#
#
# The raw data can be found [here](https://s3.amazonaws.com/dataincubator-course/coursedata/nyc_inspection_data.zip) and can be useful to look at. The file `RI_Webextract_BigApps_Latest.xls` contains a description of each of the data files and what the columns mean.

# %%
# !aws s3 sync s3://dataincubator-course/coursedata/ . --exclude '*' --include 'nyc_inspection.db'
# Out:
# download: s3://dataincubator-course/coursedata/nyc_inspection.db to ./nyc_inspection.db

# %%
#This will load the pre-existing tables
# %load_ext sql
# %sql sqlite:///nyc_inspection.db
# Out:
# 'Connected: @nyc_inspection.db'

# %% [markdown]
# To see what tables are in the database:

# %%
# %%sql
# SELECT * FROM sqlite_master WHERE "type"='table';
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [('table', 'writer', 'writer', 2, 'CREATE TABLE writer (first_name, last_name, year)'),
#  ('table', 'webextract', 'webextract', 3, 'CREATE TABLE webextract (\n\t"index" BIGINT, \n\t"CAMIS" BIGINT, \n\t"DBA" TEXT, \n\t"BORO" BIGINT, \n\t"BUILDING" TEXT, \n\t"STREET" TEXT, \n\t"ZIPC ... (58 characters truncated) ... \t"INSPDATE" TEXT, \n\t"ACTION" TEXT, \n\t"VIOLCODE" TEXT, \n\t"SCORE" FLOAT, \n\t"CURRENTGRADE" TEXT, \n\t"GRADEDATE" TEXT, \n\t"RECORDDATE" TEXT\n)'),
#  ('table', 'violations', 'violations', 24393, 'CREATE TABLE violations (\n\t"index" BIGINT, \n\t"STARTDATE" TEXT, \n\t"ENDDATE" TEXT, \n\t"CRITICALFLAG" TEXT, \n\t"VIOLATIONCODE" TEXT, \n\t"VIOLATIONDESC" TEXT\n)'),
#  ('table', 'cuisine', 'cuisine', 24426, 'CREATE TABLE cuisine (\n\t"index" BIGINT, \n\t"CUISINECODE" BIGINT, \n\t"CODEDESC" TEXT\n)'),
#  ('table', 'boroughs', 'boroughs', 24428, 'CREATE TABLE boroughs (\n   id   INT,\n   name  TEXT\n)')]

# %% [markdown]
# And to look at the format of an individual table (note that you may need to change types to get the answers in the right form):

# %%
# %%sql
# PRAGMA table_info(webextract)
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'CAMIS', 'BIGINT', 0, None, 0),
#  (2, 'DBA', 'TEXT', 0, None, 0),
#  (3, 'BORO', 'BIGINT', 0, None, 0),
#  (4, 'BUILDING', 'TEXT', 0, None, 0),
#  (5, 'STREET', 'TEXT', 0, None, 0),
#  (6, 'ZIPCODE', 'FLOAT', 0, None, 0),
#  (7, 'PHONE', 'TEXT', 0, None, 0),
#  (8, 'CUISINECODE', 'BIGINT', 0, None, 0),
#  (9, 'INSPDATE', 'TEXT', 0, None, 0),
#  (10, 'ACTION', 'TEXT', 0, None, 0),
#  (11, 'VIOLCODE', 'TEXT', 0, None, 0),
#  (12, 'SCORE', 'FLOAT', 0, None, 0),
#  (13, 'CURRENTGRADE', 'TEXT', 0, None, 0),
#  (14, 'GRADEDATE', 'TEXT', 0, None, 0),
#  (15, 'RECORDDATE', 'TEXT', 0, None, 0)]

# %% [markdown]
# ## SQLite3

# %% [markdown]
# The project should be written in SQL. Between SQLite and PostgreSQL we recommend SQLite for this project.  You can use the SQLite command prompt by running this command in bash
# ```bash
# sqlite3 cmd "DROP TABLE IF EXISTS writer;\
# CREATE TABLE IF NOT EXISTS writer (first_name, last_name, year);\
# INSERT INTO writer VALUES ('William', 'Shakespeare', 1616);\
# INSERT INTO writer VALUES ('Francis', 'Fitzgerald', 1896);\
# \
# SELECT * FROM writer;\
# "
# ```
# Alternatively, you can run bash commands in a Jupyter notebook by prepending the `!` in a code cell (notice that we conveniently get the output displayed

# %%
# !sqlite3 cmd """\
DROP TABLE IF EXISTS writer;\
CREATE TABLE IF NOT EXISTS writer (first_name, last_name, year);\
INSERT INTO writer VALUES ('William', 'Shakespeare', 1616);\
INSERT INTO writer VALUES ('Francis', 'Fitzgerald', 1896);\
\
SELECT * FROM writer;\
"""
# Out:
# William|Shakespeare|1616
# Francis|Fitzgerald|1896

# %% [markdown]
# Finally, we use the [`ipython-sql` extension](https://github.com/catherinedevlin/ipython-sql#ipython-sql) by first loading this extension and then running our code with the "magic" command in the first line
# ```python
# %%sql sqlite://
# ```
# Notice that the output table is formatted nicely as a nice HTML table.
#
# This is our recommended technique.  However, the grader is expecting python objects and you may need to use list comprehensions to reformat this output

# %%
# %%sql
# DROP TABLE IF EXISTS writer;
# CREATE TABLE IF NOT EXISTS writer (first_name, last_name, year);
# INSERT INTO writer VALUES ('William', 'Shakespeare', 1616);
# INSERT INTO writer VALUES ('Francis', 'Fitzgerald', 1896);
#
# SELECT * FROM writer;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# 1 rows affected.
# 1 rows affected.
# Done.
# [('William', 'Shakespeare', 1616), ('Francis', 'Fitzgerald', 1896)]

# %%
result = _
#This captures the output of the previous cell

# %%
type(result)
# Out:
# sql.run.ResultSet

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///nyc_inspection.db')
df = pd.read_sql_table('writer', engine)
df
# Out:
#   first_name    last_name  year
# 0    William  Shakespeare  1616
# 1    Francis   Fitzgerald  1896

# %% [markdown]
# ## How we loaded the data

# %% [markdown]
# For future reference, here is how you can load data in to SQL (with examples).  If you have a csv file you created with something like
#
# ```
# !printf "Name,Age\nAlice,3\nBob,10" > sample.csv.nogit
# ```
#
#
# Then SQLite has a convenient [`.import` function](https://sqlite.org/cli.html#csv_import) which can create tables from `.csv` files.
#
# ```bash
# sqlite> .import sample.csv.nogit sample
# sqlite> SELECT * FROM sample;
# ```
#
# The files may contain badly formatted text.  Unfortunately, this is all too common.  As a stop gap, remember that [`iconv`](https://linux.die.net/man/1/iconv) is a Unix utility that can convert files between different text encodings.
#
# Alternatively, you can also read csv files using pandas and convert that into SQL via some SQL magic (this is what we actually did).
#
# ```
# import pandas as pd
# sample = pd.read_csv('sample.csv.nogit')
# %sql DROP TABLE IF EXISTS sample
# %sql PERSIST sample
# %sql SELECT * FROM sample;
# ```

# %% [markdown]
# ## Question 1: Null entries

# %% [markdown]
# Return the number of inspections (`CAMIS`, `INSPDATE` pairs) that do not have a score - i.e. where none of the rows with those (`CAMIS`, `INSPDATE`) values has a score. Remove the corresponding rows from the data set for the rest of the questions in the assignment.
#
# **Question:** How else might we have handled this?

# %%
# %%sql
# DROP TABLE IF EXISTS null_results;
# CREATE TABLE IF NOT EXISTS null_results AS
#     SELECT CAMIS, INSPDATE
#     FROM webextract
#     WHERE (SCORE IS NULL);
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
#from sqlalchemy import create_engine
#engine = create_engine('sqlite:///nyc_inspection.db')
null_results = pd.read_sql_table('null_results', engine)
null_results
# Out:
#           CAMIS             INSPDATE
# 0      30075445  2011-04-27 00:00:00
# 1      30075445  2011-11-12 00:00:00
# 2      30075445  2011-11-12 00:00:00
# 3      40356483  2013-08-03 00:00:00
# 4      30075445  2012-05-03 00:00:00
# 5      30075445  2013-06-01 00:00:00
# 6      30075445  2011-12-21 00:00:00
# 7      30075445  2012-12-31 00:00:00
# 8      40356151  2012-02-10 00:00:00
# 9      30191841  2010-09-23 00:00:00
# 10     40356151  2012-03-31 00:00:00
# 11     40356151  2014-04-11 00:00:00
# 12     40356483  2012-03-09 00:00:00
# 13     30191841  2010-09-23 00:00:00
# 14     40356151  2014-04-11 00:00:00
# 15     40359705  2013-12-03 00:00:00
# 16     30075445  2011-03-10 00:00:00
# 17     40359705  2013-06-17 00:00:00
# 18     40356483  2013-08-03 00:00:00
# 19     40357217  2014-05-28 00:00:00
# 20     40358429  2012-08-15 00:00:00
# 21     40358429  2013-08-15 00:00:00
# 22     30191841  2010-10-22 00:00:00
# 23     40356151  2013-03-02 00:00:00
# 24     40356151  2014-04-11 00:00:00
# 25     30075445  2013-10-10 00:00:00
# 26     40359705  2013-06-04 00:00:00
# 27     40356483  2013-12-18 00:00:00
# 28     40356483  2013-12-18 00:00:00
# 29     40361521  2014-08-21 00:00:00
# ...         ...                  ...
# 33494  50014537  1900-01-01 00:00:00
# 33495  50014563  1900-01-01 00:00:00
# 33496  50014593  1900-01-01 00:00:00
# 33497  50014596  1900-01-01 00:00:00
# 33498  50014597  1900-01-01 00:00:00
# 33499  50014602  1900-01-01 00:00:00
# 33500  50014697  1900-01-01 00:00:00
# 33501  50014704  1900-01-01 00:00:00
# 33502  50014705  1900-01-01 00:00:00
# 33503  50014712  1900-01-01 00:00:00
# 33504  50014732  1900-01-01 00:00:00
# 33505  50014737  1900-01-01 00:00:00
# 33506  50014741  1900-01-01 00:00:00
# 33507  50014840  1900-01-01 00:00:00
# 33508  50014853  1900-01-01 00:00:00
# 33509  50014866  1900-01-01 00:00:00
# 33510  50014871  1900-01-01 00:00:00
# 33511  50014875  1900-01-01 00:00:00
# 33512  50014882  1900-01-01 00:00:00
# 33513  50014887  1900-01-01 00:00:00
# 33514  50014889  1900-01-01 00:00:00
# 33515  50014901  1900-01-01 00:00:00
# 33516  50014920  1900-01-01 00:00:00
# 33517  50014921  1900-01-01 00:00:00
# 33518  50014955  1900-01-01 00:00:00
# 33519  50014960  1900-01-01 00:00:00
# 33520  50014972  1900-01-01 00:00:00
# 33521  50014979  1900-01-01 00:00:00
# 33522  50015011  1900-01-01 00:00:00
# 33523  50015048  1900-01-01 00:00:00
#
# [33524 rows x 2 columns]

# %%
len(null_results)
# Out:
# 33524

# %%
def null_entries():
    return len(null_results)

grader.score('sql__null_entries', null_entries)
# Out:
# ==================
# Your score:  0
# ==================

# %%
# %%sql
# DELETE FROM webextract WHERE SCORE IS NULL;
# Out:
#  * sqlite:///nyc_inspection.db
# 33524 rows affected.
# []

# %% [markdown]
# ## Question 2: Score by zip code

# %% [markdown]
# Return a list of tuples of the form:
#
#     (zip code, mean score, number of restaurants)
#
# for each of the 87 zip codes in the city with over 100 restaurants. Use the score from the latest inspection date for each restaurant. Sort the list in ascending order by mean score.
#
# **Note:** There is an interesting discussion here about what the mean score *means* in this data set. Think about what we're actually calculating - does it represent what we're trying to understand about these zip codes?
#
# What if we use the average of a restaurant's inspections instead of the latest?
#
# **Checkpoints:**
# - Total unique restaurants: 24,361;
# - Total restaurants in valid zip codes: 19,172

# %%
# %%sql
# DROP TABLE IF EXISTS zip_scores;
# CREATE TABLE IF NOT EXISTS zip_scores AS
#     SELECT ZIPCODE, SCORE, MAX(GRADEDATE) AS recent_date
#     FROM webextract
#     GROUP BY CAMIS;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS zipcode;
# CREATE TABLE IF NOT EXISTS zipcode AS
#     SELECT ZIPCODE, AVG(SCORE), COUNT(*)
#         FROM zip_scores
#         GROUP BY ZIPCODE
#         HAVING COUNT(*) > 100
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
zipcode = pd.read_sql_table('zipcode', engine)
zipcode['ZIPCODE'] = zipcode['ZIPCODE'].astype(int)
#zipcode['ZIPCODE'] = zipcode['ZIPCODE'].astype(str)
zipcode
# Out:
#     ZIPCODE  AVG(SCORE)  COUNT(*)
# 0     10001    8.785859       495
# 1     10002   11.517621       454
# 2     10003   11.504559       658
# 3     10004   10.826772       127
# 4     10007   11.068702       131
# 5     10009   11.260726       303
# 6     10010   11.016736       239
# 7     10011   11.034014       441
# 8     10012   11.162025       395
# 9     10013   11.556034       464
# 10    10014   11.020050       399
# 11    10016   11.298507       402
# 12    10017   10.983516       364
# 13    10018   11.147692       325
# 14    10019   10.327160       648
# 15    10021   11.617450       149
# 16    10022   10.450317       473
# 17    10023   10.067708       192
# 18    10024   10.897436       195
# 19    10025   11.532751       229
# 20    10027   10.936709       158
# 21    10028   11.175355       211
# 22    10029   10.884817       191
# 23    10032   11.269565       115
# 24    10033   12.000000       113
# 25    10036   10.299484       581
# 26    10038   10.703704       162
# 27    10065   10.742515       167
# 28    10128   11.382166       157
# 29    10306   10.495238       105
# ..      ...         ...       ...
# 57    11218   10.725352       142
# 58    11219   11.811881       101
# 59    11220   12.796721       305
# 60    11221   11.330189       106
# 61    11222   10.691892       185
# 62    11223   11.303371       178
# 63    11226   10.808081       198
# 64    11229   10.615942       138
# 65    11230   11.445545       101
# 66    11231   10.000000       152
# 67    11232   11.443396       106
# 68    11234   10.082759       145
# 69    11235   11.860465       172
# 70    11236   10.066038       106
# 71    11237   10.137143       175
# 72    11238   10.593886       229
# 73    11249   11.047619       147
# 74    11354   13.063953       344
# 75    11355   13.556150       187
# 76    11358   11.204380       137
# 77    11361   10.223214       112
# 78    11368   10.417857       280
# 79    11372   11.990291       309
# 80    11373   11.461187       219
# 81    11375   11.157895       190
# 82    11377   12.053398       206
# 83    11385   11.106996       243
# 84    11430    9.400000       145
# 85    11432   10.800000       185
# 86    11435   10.873786       103
#
# [87 rows x 3 columns]

# %%
zipcode.sort_values(by=['AVG(SCORE)'])
# Out:
# Empty DataFrame
# Columns: [ZIPCODE, AVG(SCORE), COUNT(*)]
# Index: []

# %%
def score_by_zipcode():
    return zipcode.sort_values(by=['AVG(SCORE)'])
#[("11201", 9.81739130434783, 345)] * 87

grader.score('sql__score_by_zipcode', score_by_zipcode)
# Out:
# [] is too short
#
# Failed validating 'minItems' in schema:
#     {'items': {'items': [{'type': 'string'},
#                          {'type': 'number'},
#                          {'minimum': 0, 'type': 'integer'}],
#                'maxItems': 3,
#                'minItems': 3,
#                'type': 'array'},
#      'maxItems': 87,
#      'minItems': 87,
#      'type': 'array'}
#
# On instance:
#     []

# %% [markdown]
# ## Question 3: Mapping scores

# %% [markdown]
# The above are not terribly enlightening.  Use [CartoDB](http://cartodb.com/) to produce a map of average scores by zip code.  You can sign up for a free trial.
#
# You will have to use their wizard to plot the data by [zip code](https://carto.com/learn/guides/analysis/georeference). You will need to specify "USA" in the country field.  Then use the "share" button to return a link of the form [https://x.cartodb.com/](https://x.cartodb.com/).
#
# **For fun:** How do JFK, Brighton Beach, Liberty Island (home of the Statue of Liberty), Financial District, Chinatown, and Coney Island fare?
#
# **For more fun:** Plot restaurants as pins on the map, allowing the user to filter by "low", "middling", or "high"-scoring restaurants. You can use a CASE WHEN statement to create the different groups based on score thresholds.

# %%
def score_by_map():
    # must be url of the form https://x.cartodb.com/...
    return "https://cartodb.com"

grader.score('sql__score_by_map', score_by_map)

# %% [markdown]
# ## Question 4: Score by borough

# %% [markdown]
# Return a list of tuples of the form:
#
#     (borough, mean score, number of restaurants)
#
# for each of the city's five boroughs. Use the latest score for each restaurant. Sort the list in ascending order by grade.
#
# **Hint:** You will have to perform a join with the `boroughs` table. The borough names should be reported in ALL CAPS.
#
# **Checkpoint:**
# - Total restaurants in valid boroughs: 24,350

# %%
# %%sql
# DROP TABLE IF EXISTS boro_scores;
# CREATE TABLE IF NOT EXISTS boro_scores AS
#     SELECT BORO, SCORE, MAX(GRADEDATE) AS recent_date
#     FROM webextract
#     GROUP BY CAMIS;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT boroughs.name, boro_scores.SCORE
# FROM boro_scores
# LEFT JOIN boroughs ON boro_scores.BORO=boroughs.id;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [('THE BRONX', 2.0),
#  ('BROOKLYN', 23.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 5.0),
#  ('QUEENS', 13.0),
#  ('QUEENS', 10.0),
#  ('STATEN ISLAND', 12.0),
#  ('BROOKLYN', 10.0),
#  ('BROOKLYN', 12.0),
#  ('BROOKLYN', 12.0),
#  ('THE BRONX', 11.0),
#  ('BROOKLYN', 5.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 3.0),
#  ('BROOKLYN', 5.0),
#  ('BROOKLYN', 13.0),
#  ('BROOKLYN', 2.0),
#  ('QUEENS', 10.0),
#  ('BROOKLYN', 4.0),
#  ('MANHATTAN', 19.0),
#  ('BROOKLYN', 2.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 3.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 8.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 2.0),
#  ('MANHATTAN', 12.0),
#  ('THE BRONX', 10.0),
#  ('BROOKLYN', 9.0),
#  ('BROOKLYN', 11.0),
#  ('MANHATTAN', 13.0),
#  ('THE BRONX', 8.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 3.0),
#  ('STATEN ISLAND', 10.0),
#  ('QUEENS', 23.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 3.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 0.0),
#  ('STATEN ISLAND', 13.0),
#  ('STATEN ISLAND', 12.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 18.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 23.0),
#  ('BROOKLYN', 11.0),
#  ('QUEENS', 9.0),
#  ('STATEN ISLAND', 12.0),
#  ('THE BRONX', 10.0),
#  ('STATEN ISLAND', 12.0),
#  ('MANHATTAN', 56.0),
#  ('BROOKLYN', 12.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 4.0),
#  ('MANHATTAN', 23.0),
#  ('MANHATTAN', 12.0),
#  ('THE BRONX', 5.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 2.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 8.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 47.0),
#  ('BROOKLYN', 17.0),
#  ('MANHATTAN', 17.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 7.0),
#  ('STATEN ISLAND', 10.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 11.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 9.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 13.0),
#  ('QUEENS', 12.0),
#  ('THE BRONX', 17.0),
#  ('MANHATTAN', 2.0),
#  ('STATEN ISLAND', 13.0),
#  ('STATEN ISLAND', 9.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 10.0),
#  ('STATEN ISLAND', 3.0),
#  ('MANHATTAN', 5.0),
#  ('BROOKLYN', 5.0),
#  ('MANHATTAN', 2.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 6.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 14.0),
#  ('MANHATTAN', 10.0),
#  ('STATEN ISLAND', 14.0),
#  ('MANHATTAN', 21.0),
#  ('BROOKLYN', 19.0),
#  ('THE BRONX', 9.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 21.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 13.0),
#  ('QUEENS', 10.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 19.0),
#  ('MANHATTAN', 6.0),
#  ('STATEN ISLAND', 20.0),
#  ('MANHATTAN', 19.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 13.0),
#  ('QUEENS', 9.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 11.0),
#  ('THE BRONX', 10.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 4.0),
#  ('MANHATTAN', 27.0),
#  ('MANHATTAN', 8.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 11.0),
#  ('BROOKLYN', 3.0),
#  ('STATEN ISLAND', 9.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 13.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 21.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 6.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 9.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 15.0),
#  ('BROOKLYN', 11.0),
#  ('THE BRONX', 5.0),
#  ('QUEENS', 19.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 9.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 12.0),
#  ('STATEN ISLAND', 25.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 7.0),
#  ('THE BRONX', 16.0),
#  ('MANHATTAN', 3.0),
#  ('QUEENS', 15.0),
#  ('THE BRONX', 9.0),
#  ('QUEENS', 13.0),
#  ('QUEENS', 2.0),
#  ('STATEN ISLAND', 11.0),
#  ('QUEENS', 2.0),
#  ('THE BRONX', 12.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 2.0),
#  ('THE BRONX', 4.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 4.0),
#  ('MANHATTAN', 24.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 5.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 3.0),
#  ('MANHATTAN', 13.0),
#  ('STATEN ISLAND', 15.0),
#  ('QUEENS', 4.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 17.0),
#  ('STATEN ISLAND', 11.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 4.0),
#  ('BROOKLYN', 12.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 39.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 2.0),
#  ('BROOKLYN', 7.0),
#  ('QUEENS', 10.0),
#  ('THE BRONX', 5.0),
#  ('THE BRONX', 8.0),
#  ('THE BRONX', 8.0),
#  ('THE BRONX', 2.0),
#  ('THE BRONX', 11.0),
#  ('THE BRONX', 5.0),
#  ('STATEN ISLAND', 22.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 11.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 15.0),
#  ('STATEN ISLAND', 8.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 27.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 8.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 2.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 6.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 5.0),
#  ('MANHATTAN', 12.0),
#  ('THE BRONX', 10.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 19.0),
#  ('MANHATTAN', 29.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 11.0),
#  ('THE BRONX', 12.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 11.0),
#  ('MANHATTAN', 9.0),
#  ('STATEN ISLAND', 10.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 13.0),
#  ('BROOKLYN', 24.0),
#  ('THE BRONX', 12.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 25.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 7.0),
#  ('BROOKLYN', 3.0),
#  ('THE BRONX', 8.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 9.0),
#  ('THE BRONX', 13.0),
#  ('BROOKLYN', 10.0),
#  ('THE BRONX', 9.0),
#  ('QUEENS', 7.0),
#  ('BROOKLYN', 3.0),
#  ('BROOKLYN', 13.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 5.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 23.0),
#  ('MANHATTAN', 2.0),
#  ('MANHATTAN', 8.0),
#  ('THE BRONX', 12.0),
#  ('THE BRONX', 7.0),
#  ('MANHATTAN', 3.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 21.0),
#  ('BROOKLYN', 7.0),
#  ('QUEENS', 26.0),
#  ('MANHATTAN', 5.0),
#  ('THE BRONX', 11.0),
#  ('QUEENS', 9.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 2.0),
#  ('MANHATTAN', 5.0),
#  ('BROOKLYN', 12.0),
#  ('STATEN ISLAND', 5.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 16.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 3.0),
#  ('STATEN ISLAND', 10.0),
#  ('QUEENS', 17.0),
#  ('BROOKLYN', 5.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 26.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 5.0),
#  ('QUEENS', 13.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 13.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 2.0),
#  ('BROOKLYN', 12.0),
#  ('STATEN ISLAND', 20.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 7.0),
#  ('BROOKLYN', 10.0),
#  ('BROOKLYN', 26.0),
#  ('QUEENS', 9.0),
#  ('STATEN ISLAND', 5.0),
#  ('BROOKLYN', 11.0),
#  ('THE BRONX', 13.0),
#  ('QUEENS', 8.0),
#  ('MANHATTAN', 10.0),
#  ('STATEN ISLAND', 10.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 7.0),
#  ('QUEENS', 11.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 40.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 38.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 2.0),
#  ('QUEENS', 5.0),
#  ('THE BRONX', 2.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 12.0),
#  ('STATEN ISLAND', 12.0),
#  ('QUEENS', 5.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 9.0),
#  ('STATEN ISLAND', 11.0),
#  ('MANHATTAN', 40.0),
#  ('BROOKLYN', 12.0),
#  ('BROOKLYN', 8.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 2.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 45.0),
#  ('BROOKLYN', 17.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 23.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 13.0),
#  ('THE BRONX', 3.0),
#  ('BROOKLYN', 12.0),
#  ('QUEENS', 21.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 20.0),
#  ('MANHATTAN', 13.0),
#  ('THE BRONX', 15.0),
#  ('MANHATTAN', 0.0),
#  ('THE BRONX', 8.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 24.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 19.0),
#  ('BROOKLYN', 3.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 12.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 4.0),
#  ('THE BRONX', 7.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 9.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', -1.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 22.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 9.0),
#  ('BROOKLYN', 6.0),
#  ('BROOKLYN', 12.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 33.0),
#  ('MANHATTAN', 20.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 7.0),
#  ('STATEN ISLAND', 10.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 5.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 12.0),
#  ('STATEN ISLAND', 12.0),
#  ('BROOKLYN', 8.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 27.0),
#  ('MANHATTAN', 0.0),
#  ('THE BRONX', 13.0),
#  ('QUEENS', 9.0),
#  ('THE BRONX', 20.0),
#  ('STATEN ISLAND', 11.0),
#  ('QUEENS', 2.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 9.0),
#  ('BROOKLYN', 11.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 5.0),
#  ('MANHATTAN', 5.0),
#  ('QUEENS', 9.0),
#  ('QUEENS', 18.0),
#  ('QUEENS', 8.0),
#  ('MANHATTAN', 20.0),
#  ('QUEENS', 6.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 16.0),
#  ('BROOKLYN', 12.0),
#  ('THE BRONX', 7.0),
#  ('BROOKLYN', 9.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 9.0),
#  ('MANHATTAN', 38.0),
#  ('QUEENS', 10.0),
#  ('BROOKLYN', 13.0),
#  ('STATEN ISLAND', 11.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 5.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 19.0),
#  ('QUEENS', 12.0),
#  ('THE BRONX', 12.0),
#  ('MANHATTAN', 2.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 12.0),
#  ('THE BRONX', 7.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 11.0),
#  ('BROOKLYN', 13.0),
#  ('THE BRONX', 9.0),
#  ('MANHATTAN', 7.0),
#  ('THE BRONX', 20.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 17.0),
#  ('MANHATTAN', 8.0),
#  ('BROOKLYN', 19.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 27.0),
#  ('QUEENS', 8.0),
#  ('MANHATTAN', 2.0),
#  ('BROOKLYN', 4.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 51.0),
#  ('MANHATTAN', 4.0),
#  ('MANHATTAN', 7.0),
#  ('BROOKLYN', 2.0),
#  ('QUEENS', 8.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 8.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 9.0),
#  ('STATEN ISLAND', 13.0),
#  ('MANHATTAN', 21.0),
#  ('QUEENS', 8.0),
#  ('MANHATTAN', 6.0),
#  ('STATEN ISLAND', 22.0),
#  ('BROOKLYN', 13.0),
#  ('BROOKLYN', 14.0),
#  ('BROOKLYN', 2.0),
#  ('BROOKLYN', 8.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 2.0),
#  ('MANHATTAN', 12.0),
#  ('THE BRONX', 5.0),
#  ('THE BRONX', 11.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 0.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 11.0),
#  ('THE BRONX', 36.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 2.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 18.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 11.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 4.0),
#  ('STATEN ISLAND', 7.0),
#  ('STATEN ISLAND', 8.0),
#  ('BROOKLYN', 11.0),
#  ('MANHATTAN', 13.0),
#  ('THE BRONX', 6.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 8.0),
#  ('STATEN ISLAND', 21.0),
#  ('BROOKLYN', 3.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 22.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 9.0),
#  ('QUEENS', 2.0),
#  ('BROOKLYN', 23.0),
#  ('THE BRONX', 8.0),
#  ('BROOKLYN', 24.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 21.0),
#  ('BROOKLYN', 10.0),
#  ('BROOKLYN', 11.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 19.0),
#  ('QUEENS', 14.0),
#  ('QUEENS', 12.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 15.0),
#  ('BROOKLYN', 11.0),
#  ('BROOKLYN', 11.0),
#  ('STATEN ISLAND', 7.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 5.0),
#  ('MANHATTAN', 3.0),
#  ('MANHATTAN', 9.0),
#  ('STATEN ISLAND', 12.0),
#  ('BROOKLYN', 26.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 2.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 10.0),
#  ('THE BRONX', 5.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 13.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 7.0),
#  ('THE BRONX', 2.0),
#  ('STATEN ISLAND', 20.0),
#  ('MANHATTAN', 9.0),
#  ('STATEN ISLAND', 11.0),
#  ('THE BRONX', 3.0),
#  ('STATEN ISLAND', 7.0),
#  ('QUEENS', 9.0),
#  ('BROOKLYN', 11.0),
#  ('QUEENS', 13.0),
#  ('THE BRONX', 9.0),
#  ('MANHATTAN', 16.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 13.0),
#  ('QUEENS', 11.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 10.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 17.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 12.0),
#  ('BROOKLYN', 18.0),
#  ('MANHATTAN', 5.0),
#  ('MANHATTAN', 9.0),
#  ('THE BRONX', 5.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 8.0),
#  ('QUEENS', 10.0),
#  ('BROOKLYN', 3.0),
#  ('MANHATTAN', 17.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 5.0),
#  ('QUEENS', 2.0),
#  ('MANHATTAN', 11.0),
#  ('THE BRONX', 7.0),
#  ('MANHATTAN', 13.0),
#  ('THE BRONX', 5.0),
#  ('BROOKLYN', 4.0),
#  ('MANHATTAN', 12.0),
#  ('STATEN ISLAND', 19.0),
#  ('MANHATTAN', 16.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 10.0),
#  ('THE BRONX', 9.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 5.0),
#  ('THE BRONX', 12.0),
#  ('THE BRONX', 7.0),
#  ('QUEENS', 19.0),
#  ('STATEN ISLAND', 7.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 9.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 9.0),
#  ('THE BRONX', 5.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 11.0),
#  ('MANHATTAN', 11.0),
#  ('THE BRONX', 23.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 19.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 10.0),
#  ('THE BRONX', 9.0),
#  ('BROOKLYN', 12.0),
#  ('THE BRONX', 3.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 12.0),
#  ('THE BRONX', 9.0),
#  ('MANHATTAN', 25.0),
#  ('MANHATTAN', 7.0),
#  ('THE BRONX', 20.0),
#  ('STATEN ISLAND', 12.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 4.0),
#  ('BROOKLYN', 9.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 3.0),
#  ('BROOKLYN', 4.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 5.0),
#  ('MANHATTAN', 19.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 21.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 6.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 7.0),
#  ('THE BRONX', 7.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 2.0),
#  ('MANHATTAN', 5.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 12.0),
#  ('THE BRONX', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 8.0),
#  ('THE BRONX', 13.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 2.0),
#  ('STATEN ISLAND', 11.0),
#  ('QUEENS', 39.0),
#  ('MANHATTAN', 25.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 9.0),
#  ('MANHATTAN', 8.0),
#  ('BROOKLYN', 10.0),
#  ('QUEENS', 9.0),
#  ('MANHATTAN', 4.0),
#  ('MANHATTAN', 4.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 13.0),
#  ('THE BRONX', 12.0),
#  ('MANHATTAN', 13.0),
#  ('STATEN ISLAND', 4.0),
#  ('MANHATTAN', 7.0),
#  ('BROOKLYN', 12.0),
#  ('STATEN ISLAND', 12.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 12.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 18.0),
#  ('QUEENS', 11.0),
#  ('QUEENS', 24.0),
#  ('THE BRONX', 11.0),
#  ('MANHATTAN', 3.0),
#  ('MANHATTAN', 9.0),
#  ('STATEN ISLAND', 11.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 18.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 6.0),
#  ('STATEN ISLAND', 13.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 14.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 26.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 2.0),
#  ('BROOKLYN', 5.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 6.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 7.0),
#  ('THE BRONX', 5.0),
#  ('QUEENS', 8.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 11.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 7.0),
#  ('BROOKLYN', 12.0),
#  ('MANHATTAN', 23.0),
#  ('THE BRONX', 3.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 8.0),
#  ('MANHATTAN', 27.0),
#  ('QUEENS', 3.0),
#  ('STATEN ISLAND', 12.0),
#  ('STATEN ISLAND', 8.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 9.0),
#  ('STATEN ISLAND', 10.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 9.0),
#  ('THE BRONX', 10.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 0.0),
#  ('QUEENS', 7.0),
#  ('BROOKLYN', 7.0),
#  ('STATEN ISLAND', 23.0),
#  ('MANHATTAN', 25.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 11.0),
#  ('BROOKLYN', 2.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 40.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 19.0),
#  ('MANHATTAN', 7.0),
#  ('BROOKLYN', 11.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 2.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 4.0),
#  ('BROOKLYN', 12.0),
#  ('QUEENS', 13.0),
#  ('QUEENS', 8.0),
#  ('MANHATTAN', 8.0),
#  ('BROOKLYN', 19.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 7.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 11.0),
#  ('BROOKLYN', 19.0),
#  ('QUEENS', 13.0),
#  ('BROOKLYN', 4.0),
#  ('MANHATTAN', 15.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 12.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 2.0),
#  ('MANHATTAN', 98.0),
#  ('BROOKLYN', 4.0),
#  ('MANHATTAN', 2.0),
#  ('BROOKLYN', 9.0),
#  ('MANHATTAN', 10.0),
#  ('BROOKLYN', 11.0),
#  ('THE BRONX', 25.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 11.0),
#  ('QUEENS', 24.0),
#  ('QUEENS', 10.0),
#  ('THE BRONX', 10.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 14.0),
#  ('MANHATTAN', 17.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 3.0),
#  ('QUEENS', 7.0),
#  ('MANHATTAN', 17.0),
#  ('QUEENS', 7.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 0.0),
#  ('BROOKLYN', 10.0),
#  ('QUEENS', 9.0),
#  ('MANHATTAN', 11.0),
#  ('THE BRONX', 11.0),
#  ('BROOKLYN', 9.0),
#  ('THE BRONX', 9.0),
#  ('MANHATTAN', 26.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 12.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 10.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 11.0),
#  ('BROOKLYN', 5.0),
#  ('QUEENS', 19.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 7.0),
#  ('BROOKLYN', 12.0),
#  ('BROOKLYN', 7.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 10.0),
#  ('MANHATTAN', 7.0),
#  ('MANHATTAN', 5.0),
#  ('STATEN ISLAND', 18.0),
#  ('MANHATTAN', 11.0),
#  ('STATEN ISLAND', 7.0),
#  ('MANHATTAN', 13.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 12.0),
#  ('QUEENS', 8.0),
#  ('QUEENS', 2.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 12.0),
#  ('QUEENS', 8.0),
#  ('STATEN ISLAND', 8.0),
#  ('BROOKLYN', 16.0),
#  ('QUEENS', 8.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 9.0),
#  ('MANHATTAN', 13.0),
#  ('THE BRONX', 10.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 4.0),
#  ('THE BRONX', 12.0),
#  ('THE BRONX', 17.0),
#  ('MANHATTAN', 9.0),
#  ('BROOKLYN', 13.0),
#  ('MANHATTAN', 13.0),
#  ('BROOKLYN', 24.0),
#  ('QUEENS', 10.0),
#  ('QUEENS', 12.0),
#  ('MANHATTAN', 7.0),
#  ('QUEENS', 29.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 10.0),
#  ('MANHATTAN', 5.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 12.0),
#  ('QUEENS', 13.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 25.0),
#  ('MANHATTAN', 12.0),
#  ('MANHATTAN', 8.0),
#  ('MANHATTAN', 13.0),
#  ('QUEENS', 9.0),
#  ('QUEENS', 13.0),
#  ('QUEENS', 20.0),
#  ('QUEENS', 13.0),
#  ('BROOKLYN', 10.0),
#  ('BROOKLYN', 10.0),
#  ('MANHATTAN', 12.0),
#  ('BROOKLYN', 2.0),
#  ('QUEENS', 3.0),
#  ('MANHATTAN', 11.0),
#  ('MANHATTAN', 9.0),
#  ('QUEENS', 9.0),
#  ('QUEENS', 14.0),
#  ('THE BRONX', 11.0),
#  ('QUEENS', 12.0),
#  ('BROOKLYN', 10.0),
#  ...]

# %%
# %%sql
# DROP TABLE IF EXISTS boros;
# CREATE TABLE IF NOT EXISTS boros AS
#     SELECT boroughs.name, boro_scores.SCORE
#     FROM boro_scores
#     LEFT JOIN boroughs ON boro_scores.BORO=boroughs.id;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS boro_avg;
# CREATE TABLE IF NOT EXISTS boro_avg AS
#     SELECT name, AVG(SCORE), COUNT(*)
#         FROM boros
#         GROUP BY name
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
boro = pd.read_sql_table('boro_avg', engine)
boro = boro.drop(boro.index[0])
boro = boro.sort_values(by=['AVG(SCORE)'])
boro
# Out:
#             name  AVG(SCORE)  COUNT(*)
# 5      THE BRONX   10.231039      2281
# 2      MANHATTAN   10.870286      9891
# 1       BROOKLYN   10.959651      5849
# 3         QUEENS   11.274506      5417
# 4  STATEN ISLAND   11.464912       912

# %%
def score_by_borough():
    return boro
#[("MANHATTAN", 10.7269875502402, 10201)] * 5

grader.score('sql__score_by_borough', score_by_borough)
# Out:
# ==================
# Your score:  0.7
# ==================

# %% [markdown]
# ## Question 5: Violations by cuisine

# %% [markdown]
# We want to look at violations themselves now.  We'll need to think more carefully about what we're measuring, since most restaurants have many inspections with possibly multiple violations per inspection, or long stretches of inspections with no violations.
#
# There are many ways to deal with this normalization issue, but we'll go with a fairly straightforward one: dividing the number of violations by the length of time (in years) the restaurant has been open.  As a proxy for the length, we'll look at the difference between the oldest and newest inspection date, treating anything less than 30 days as 30 days (to account for those that were only inspected once, we'll assume everything was open for at least a month).
#
# Since there are so many restaurants, we'll group them by cuisine and do a weighted average by computing
#
#     (total violations for a cuisine) / (total restaurant-years for that cuisine)
#
# Return a list of 75 tuples of the form
#
#     (cuisine name, reports per restaurant-year)
#
# for cuisines with at least 100 violations total, ordered by increasing number of reports per restaurant-year
#
# **Note:** This isn't the only way to normalize things.  How would other ways affect the computation?  If you similarly wanted to compute an average score by cuisine, how might you go about doing that?
#
# **Checkpoint:**
# - Total entries from valid cuisines: 522,410

# %%
# %%sql
# DROP TABLE IF EXISTS tot_cuisines;
# CREATE TABLE IF NOT EXISTS tot_cuisines AS
#     SELECT CAMIS, CUISINECODE, GRADEDATE
#     FROM webextract
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS tot_cuisines2;
# CREATE TABLE IF NOT EXISTS tot_cuisines2 AS
#     SELECT tot_cuisines.CAMIS, tot_cuisines.GRADEDATE, cuisine.CODEDESC
#     FROM tot_cuisines
#     LEFT JOIN cuisine ON tot_cuisines.CUISINECODE=cuisine.CUISINECODE;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS tot_cuisines3;
# CREATE TABLE IF NOT EXISTS tot_cuisines3 AS
#     SELECT CAMIS, CODEDESC, COUNT(*), JULIANDAY(MAX(GRADEDATE)) - JULIANDAY(MIN(GRADEDATE)) AS DIFFERENCE FROM tot_cuisines2
#     GROUP BY CAMIS;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS camis_avg;
# CREATE TABLE IF NOT EXISTS camis_avg AS
#     SELECT CODEDESC, COUNT(*) - 1 AS AVG FROM tot_cuisines3
#     GROUP BY CAMIS;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM tot_cuisines3
# LIMIT 3;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [(30075445, 'Bakery', 22, 1089.0),
#  (30112340, 'Hamburgers', 19, 930.0),
#  (30191841, 'American ', 31, 1067.0)]

# %%
camis_avg = pd.read_sql_table('tot_cuisines3', engine)
camis_avg
# Out:
#           CAMIS                                           CODEDESC  COUNT(*)  \
# 0      30075445                                             Bakery        22
# 1      30112340                                         Hamburgers        19
# 2      30191841                                          American         31
# 3      40356018                                          American         14
# 4      40356068                                      Jewish/Kosher        27
# 5      40356151                                          American         22
# 6      40356442                                      Jewish/Kosher        11
# 7      40356483                                       Delicatessen        34
# 8      40356649                                          American         21
# 9      40356731                    Ice Cream, Gelato, Yogurt, Ices        11
# 10     40357217                                          American          7
# 11     40357437                                          American          7
# 12     40358429                                            Chinese        48
# 13     40359480                                          American          9
# 14     40359705                                            Hotdogs        22
# 15     40360045                                      Jewish/Kosher        38
# 16     40360076                    Ice Cream, Gelato, Yogurt, Ices        19
# 17     40361322                    Ice Cream, Gelato, Yogurt, Ices        14
# 18     40361390                                       Delicatessen        18
# 19     40361521                                          American         44
# 20     40361606                                          American         19
# 21     40361618                                       Delicatessen         9
# 22     40361708                                       Delicatessen        32
# 23     40361998                                       Delicatessen         8
# 24     40362098                                            Chicken        56
# 25     40362264                                          American         19
# 26     40362274                                          American          7
# 27     40362344                                         Hamburgers        10
# 28     40362432                                            Chinese        41
# 29     40362715                                            Turkish        26
# ...         ...                                                ...       ...
# 24331  50014014                                            Chinese         1
# 24332  50014020                                             Indian         1
# 24333  50014021                                            Spanish         1
# 24334  50014038                                            Mexican         2
# 24335  50014083                                      Pizza/Italian         2
# 24336  50014086                                           Japanese         1
# 24337  50014089                                             Korean         1
# 24338  50014098                                             Donuts         4
# 24339  50014104                                          American          4
# 24340  50014153  Latin (Cuban, Dominican, Puerto Rican, South &...         4
# 24341  50014187                                          American          4
# 24342  50014212                                            Chicken         5
# 24343  50014220                                   Chinese/Japanese         5
# 24344  50014226                                            Spanish         4
# 24345  50014233                                              Other         3
# 24346  50014251                                              Other         3
# 24347  50014266                                          American          8
# 24348  50014289                                          American          3
# 24349  50014316                                              Other         1
# 24350  50014318                                            Spanish         2
# 24351  50014331                                            Chinese         4
# 24352  50014333                                              Other         1
# 24353  50014385                                            Italian         6
# 24354  50014414                                          American          4
# 24355  50014461                                            Chinese         6
# 24356  50014465                                              Other         1
# 24357  50014483                                              Pizza         1
# 24358  50014494                                              Other         3
# 24359  50014708                                             Indian         4
# 24360  50014831                                            Mexican         2
#
#        DIFFERENCE
# 0          1089.0
# 1           930.0
# 2          1067.0
# 3           972.0
# 4           568.0
# 5           986.0
# 6           847.0
# 7           958.0
# 8          1066.0
# 9           872.0
# 10          712.0
# 11          852.0
# 12          748.0
# 13          862.0
# 14          669.0
# 15         1010.0
# 16          935.0
# 17          937.0
# 18          955.0
# 19          887.0
# 20         1038.0
# 21         1052.0
# 22         1000.0
# 23         1079.0
# 24          949.0
# 25          561.0
# 26         1072.0
# 27          908.0
# 28         1006.0
# 29          951.0
# ...           ...
# 24331         NaN
# 24332         NaN
# 24333         NaN
# 24334         0.0
# 24335         NaN
# 24336         NaN
# 24337         NaN
# 24338         NaN
# 24339         NaN
# 24340         NaN
# 24341         NaN
# 24342         NaN
# 24343         NaN
# 24344         NaN
# 24345         NaN
# 24346         NaN
# 24347         NaN
# 24348         NaN
# 24349         NaN
# 24350         NaN
# 24351         NaN
# 24352         NaN
# 24353         NaN
# 24354         NaN
# 24355         NaN
# 24356         NaN
# 24357         NaN
# 24358         NaN
# 24359         NaN
# 24360         0.0
#
# [24361 rows x 4 columns]

# %%
cuisine_sum = camis_avg.groupby('CODEDESC').sum()
cuisine_sum
# Out:
#                                                            CAMIS  COUNT(*)  \
# CODEDESC
# Afghan                                                 620663014       276
# African                                               3252533652      1788
# American                                            262331091987    119202
# Armenian                                              2231014294       574
# Asian                                                14148173376      7339
# Australian                                             664580810       233
# Bagels/Pretzels                                       6928286462      3533
# Bakery                                               28317041274     15513
# Bangladeshi                                           1254128952       779
# Barbecue                                              1976011843       775
# Basque                                                  41523524        35
# Bottled beverages, including water, sodas, juic...    3085459635       988
# Brazilian                                             1173292145       631
# Café/Coffee/Tea                                      49491455503     14229
# Cajun                                                  372891755       168
# Californian                                             50001859         2
# Caribbean                                            27844746789     15465
# Chicken                                              18399453388      7034
# Chilean                                                 50007362         3
# Chinese                                             104038263902     59270
# Chinese/Cuban                                          742566743       424
# Chinese/Japanese                                      2210798558      1272
# Continental                                           2226746045       941
# Creole                                                 913226033       660
# Creole/Cajun                                            83320486        48
# Czech                                                  248530154       119
# Delicatessen                                         13287323303      9226
# Donuts                                               19368420865      6082
# Eastern European                                      2858748676      1395
# Egyptian                                               678763576       310
# ...                                                          ...       ...
# Middle Eastern                                        7140433978      2996
# Moroccan                                               762684578       263
# Not Listed/Not Applicable                              614505060       118
# Nuts/Confectionary                                     207805708        60
# Other                                                15916459776      1767
# Pakistani                                             1228002829       787
# Pancakes/Waffles                                       573300615       396
# Peruvian                                              2726899384      1814
# Pizza                                                50748367162     24594
# Pizza/Italian                                        19458462162     10189
# Polish                                                1124211000       686
# Portuguese                                             345760342       245
# Russian                                               3822054385      1884
# Salads                                                1819346025       543
# Sandwiches                                           19725083880      6368
# Sandwiches/Salads/Mixed Buffet                       10648677767      2976
# Scandinavian                                           298349627       144
# Seafood                                               5764459399      3075
# Soul Food                                             1694287727       985
# Soups                                                  215724557        43
# Soups & Sandwiches                                    2257299314       567
# Southwestern                                           481833076       194
# Spanish                                              28438909292     12499
# Steak                                                 3476298381      1711
# Tapas                                                 1251735311       544
# Tex-Mex                                               6144631612      2708
# Thai                                                 11901344190      6640
# Turkish                                               2863029566      1467
# Vegetarian                                            4350905883      1901
# Vietnamese/Cambodian/Malaysia                         2674682930      1780
#
#                                                     DIFFERENCE
# CODEDESC
# Afghan                                                  7855.0
# African                                                46983.0
# American                                             4421776.0
# Armenian                                               19525.0
# Asian                                                 185484.0
# Australian                                              7270.0
# Bagels/Pretzels                                       123761.0
# Bakery                                                514609.0
# Bangladeshi                                            18697.0
# Barbecue                                               30434.0
# Basque                                                  1005.0
# Bottled beverages, including water, sodas, juic...     47450.0
# Brazilian                                              17971.0
# Café/Coffee/Tea                                       761711.0
# Cajun                                                   6432.0
# Californian                                                0.0
# Caribbean                                             453214.0
# Chicken                                               253037.0
# Chilean                                                    0.0
# Chinese                                              1565051.0
# Chinese/Cuban                                          10413.0
# Chinese/Japanese                                       28171.0
# Continental                                            32475.0
# Creole                                                 14648.0
# Creole/Cajun                                            1368.0
# Czech                                                   4320.0
# Delicatessen                                          266070.0
# Donuts                                                370335.0
# Eastern European                                       40982.0
# Egyptian                                               11491.0
# ...                                                        ...
# Middle Eastern                                        103568.0
# Moroccan                                                8362.0
# Not Listed/Not Applicable                               5861.0
# Nuts/Confectionary                                      4910.0
# Other                                                  62004.0
# Pakistani                                              18729.0
# Pancakes/Waffles                                       12143.0
# Peruvian                                               46871.0
# Pizza                                                 881634.0
# Pizza/Italian                                         328022.0
# Polish                                                 23633.0
# Portuguese                                              6145.0
# Russian                                                61406.0
# Salads                                                 19627.0
# Sandwiches                                            350212.0
# Sandwiches/Salads/Mixed Buffet                        140463.0
# Scandinavian                                            4831.0
# Seafood                                               100050.0
# Soul Food                                              29702.0
# Soups                                                   2886.0
# Soups & Sandwiches                                     34199.0
# Southwestern                                            6313.0
# Spanish                                               316890.0
# Steak                                                  66236.0
# Tapas                                                  17431.0
# Tex-Mex                                                91531.0
# Thai                                                  180027.0
# Turkish                                                43744.0
# Vegetarian                                             63280.0
# Vietnamese/Cambodian/Malaysia                          49114.0
#
# [84 rows x 3 columns]

# %%
cuisine_sum['AVG'] = cuisine_avg['COUNT(*)']/(cuisine_avg['DIFFERENCE']/365)
cuisine_sum
# Out:
#                                                            CAMIS  COUNT(*)  \
# CODEDESC
# Afghan                                                 620663014       276
# African                                               3252533652      1788
# American                                            262331091987    119202
# Armenian                                              2231014294       574
# Asian                                                14148173376      7339
# Australian                                             664580810       233
# Bagels/Pretzels                                       6928286462      3533
# Bakery                                               28317041274     15513
# Bangladeshi                                           1254128952       779
# Barbecue                                              1976011843       775
# Basque                                                  41523524        35
# Bottled beverages, including water, sodas, juic...    3085459635       988
# Brazilian                                             1173292145       631
# Café/Coffee/Tea                                      49491455503     14229
# Cajun                                                  372891755       168
# Californian                                             50001859         2
# Caribbean                                            27844746789     15465
# Chicken                                              18399453388      7034
# Chilean                                                 50007362         3
# Chinese                                             104038263902     59270
# Chinese/Cuban                                          742566743       424
# Chinese/Japanese                                      2210798558      1272
# Continental                                           2226746045       941
# Creole                                                 913226033       660
# Creole/Cajun                                            83320486        48
# Czech                                                  248530154       119
# Delicatessen                                         13287323303      9226
# Donuts                                               19368420865      6082
# Eastern European                                      2858748676      1395
# Egyptian                                               678763576       310
# ...                                                          ...       ...
# Middle Eastern                                        7140433978      2996
# Moroccan                                               762684578       263
# Not Listed/Not Applicable                              614505060       118
# Nuts/Confectionary                                     207805708        60
# Other                                                15916459776      1767
# Pakistani                                             1228002829       787
# Pancakes/Waffles                                       573300615       396
# Peruvian                                              2726899384      1814
# Pizza                                                50748367162     24594
# Pizza/Italian                                        19458462162     10189
# Polish                                                1124211000       686
# Portuguese                                             345760342       245
# Russian                                               3822054385      1884
# Salads                                                1819346025       543
# Sandwiches                                           19725083880      6368
# Sandwiches/Salads/Mixed Buffet                       10648677767      2976
# Scandinavian                                           298349627       144
# Seafood                                               5764459399      3075
# Soul Food                                             1694287727       985
# Soups                                                  215724557        43
# Soups & Sandwiches                                    2257299314       567
# Southwestern                                           481833076       194
# Spanish                                              28438909292     12499
# Steak                                                 3476298381      1711
# Tapas                                                 1251735311       544
# Tex-Mex                                               6144631612      2708
# Thai                                                 11901344190      6640
# Turkish                                               2863029566      1467
# Vegetarian                                            4350905883      1901
# Vietnamese/Cambodian/Malaysia                         2674682930      1780
#
#                                                     DIFFERENCE        AVG
# CODEDESC
# Afghan                                                  7855.0  12.824952
# African                                                46983.0  13.705349
# American                                             4421776.0   9.646183
# Armenian                                               19525.0  10.511359
# Asian                                                 185484.0  14.216914
# Australian                                              7270.0  11.698074
# Bagels/Pretzels                                       123761.0  10.355715
# Bakery                                                514609.0  10.953590
# Bangladeshi                                            18697.0  15.207520
# Barbecue                                               30434.0   9.092645
# Basque                                                  1005.0  12.711443
# Bottled beverages, including water, sodas, juic...     47450.0   7.072222
# Brazilian                                              17971.0  11.866598
# Café/Coffee/Tea                                       761711.0   6.711127
# Cajun                                                   6432.0   9.533582
# Californian                                                0.0        inf
# Caribbean                                             453214.0  12.301114
# Chicken                                               253037.0   9.976872
# Chilean                                                    0.0        inf
# Chinese                                              1565051.0  13.684387
# Chinese/Cuban                                          10413.0  14.862191
# Chinese/Japanese                                       28171.0  15.491931
# Continental                                            32475.0  10.372899
# Creole                                                 14648.0  16.445931
# Creole/Cajun                                            1368.0  12.807018
# Czech                                                   4320.0  10.054398
# Delicatessen                                          266070.0  12.576555
# Donuts                                                370335.0   5.955119
# Eastern European                                       40982.0  12.233213
# Egyptian                                               11491.0   9.846837
# ...                                                        ...        ...
# Middle Eastern                                        103568.0  10.429903
# Moroccan                                                8362.0  10.804620
# Not Listed/Not Applicable                               5861.0   6.823677
# Nuts/Confectionary                                      4910.0   4.460285
# Other                                                  62004.0   7.306046
# Pakistani                                              18729.0  15.337445
# Pancakes/Waffles                                       12143.0  11.903154
# Peruvian                                               46871.0  13.684774
# Pizza                                                 881634.0  10.045228
# Pizza/Italian                                         328022.0  11.287882
# Polish                                                 23633.0  10.594931
# Portuguese                                              6145.0  14.552482
# Russian                                                61406.0  10.946926
# Salads                                                 19627.0   9.605490
# Sandwiches                                            350212.0   6.622560
# Sandwiches/Salads/Mixed Buffet                        140463.0   7.541548
# Scandinavian                                            4831.0  10.879735
# Seafood                                               100050.0  10.805709
# Soul Food                                              29702.0  11.499184
# Soups                                                   2886.0   5.438323
# Soups & Sandwiches                                     34199.0   6.051493
# Southwestern                                            6313.0  11.216537
# Spanish                                               316890.0  13.654265
# Steak                                                  66236.0   9.428634
# Tapas                                                  17431.0  11.391200
# Tex-Mex                                                91531.0  10.415812
# Thai                                                  180027.0  12.971096
# Turkish                                                43744.0  12.055186
# Vegetarian                                             63280.0  10.636047
# Vietnamese/Cambodian/Malaysia                          49114.0  13.228407
#
# [84 rows x 4 columns]

# %%
cuisine_avg = cuisine_sum.drop(columns=['CAMIS', 'DIFFERENCE'])
cuisine_avg
# Out:
#                                                     COUNT(*)        AVG
# CODEDESC
# Afghan                                                   276  12.824952
# African                                                 1788  13.705349
# American                                              119202   9.646183
# Armenian                                                 574  10.511359
# Asian                                                   7339  14.216914
# Australian                                               233  11.698074
# Bagels/Pretzels                                         3533  10.355715
# Bakery                                                 15513  10.953590
# Bangladeshi                                              779  15.207520
# Barbecue                                                 775   9.092645
# Basque                                                    35  12.711443
# Bottled beverages, including water, sodas, juic...       988   7.072222
# Brazilian                                                631  11.866598
# Café/Coffee/Tea                                        14229   6.711127
# Cajun                                                    168   9.533582
# Californian                                                2        inf
# Caribbean                                              15465  12.301114
# Chicken                                                 7034   9.976872
# Chilean                                                    3        inf
# Chinese                                                59270  13.684387
# Chinese/Cuban                                            424  14.862191
# Chinese/Japanese                                        1272  15.491931
# Continental                                              941  10.372899
# Creole                                                   660  16.445931
# Creole/Cajun                                              48  12.807018
# Czech                                                    119  10.054398
# Delicatessen                                            9226  12.576555
# Donuts                                                  6082   5.955119
# Eastern European                                        1395  12.233213
# Egyptian                                                 310   9.846837
# ...                                                      ...        ...
# Middle Eastern                                          2996  10.429903
# Moroccan                                                 263  10.804620
# Not Listed/Not Applicable                                118   6.823677
# Nuts/Confectionary                                        60   4.460285
# Other                                                   1767   7.306046
# Pakistani                                                787  15.337445
# Pancakes/Waffles                                         396  11.903154
# Peruvian                                                1814  13.684774
# Pizza                                                  24594  10.045228
# Pizza/Italian                                          10189  11.287882
# Polish                                                   686  10.594931
# Portuguese                                               245  14.552482
# Russian                                                 1884  10.946926
# Salads                                                   543   9.605490
# Sandwiches                                              6368   6.622560
# Sandwiches/Salads/Mixed Buffet                          2976   7.541548
# Scandinavian                                             144  10.879735
# Seafood                                                 3075  10.805709
# Soul Food                                                985  11.499184
# Soups                                                     43   5.438323
# Soups & Sandwiches                                       567   6.051493
# Southwestern                                             194  11.216537
# Spanish                                                12499  13.654265
# Steak                                                   1711   9.428634
# Tapas                                                    544  11.391200
# Tex-Mex                                                 2708  10.415812
# Thai                                                    6640  12.971096
# Turkish                                                 1467  12.055186
# Vegetarian                                              1901  10.636047
# Vietnamese/Cambodian/Malaysia                           1780  13.228407
#
# [84 rows x 2 columns]

# %%
cuisavg_100 = cuisine_avg.loc[cuisine_avg['COUNT(*)'] > 100]
cuisavg_100
# Out:
#                                                     COUNT(*)        AVG
# CODEDESC
# Afghan                                                   276  12.824952
# African                                                 1788  13.705349
# American                                              119202   9.646183
# Armenian                                                 574  10.511359
# Asian                                                   7339  14.216914
# Australian                                               233  11.698074
# Bagels/Pretzels                                         3533  10.355715
# Bakery                                                 15513  10.953590
# Bangladeshi                                              779  15.207520
# Barbecue                                                 775   9.092645
# Bottled beverages, including water, sodas, juic...       988   7.072222
# Brazilian                                                631  11.866598
# Café/Coffee/Tea                                        14229   6.711127
# Cajun                                                    168   9.533582
# Caribbean                                              15465  12.301114
# Chicken                                                 7034   9.976872
# Chinese                                                59270  13.684387
# Chinese/Cuban                                            424  14.862191
# Chinese/Japanese                                        1272  15.491931
# Continental                                              941  10.372899
# Creole                                                   660  16.445931
# Czech                                                    119  10.054398
# Delicatessen                                            9226  12.576555
# Donuts                                                  6082   5.955119
# Eastern European                                        1395  12.233213
# Egyptian                                                 310   9.846837
# English                                                  318   9.415152
# Ethiopian                                                286   9.045143
# Filipino                                                 542  13.386791
# French                                                  7010  10.388353
# ...                                                      ...        ...
# Mediterranean                                           3925  11.055063
# Mexican                                                17472  12.079827
# Middle Eastern                                          2996  10.429903
# Moroccan                                                 263  10.804620
# Not Listed/Not Applicable                                118   6.823677
# Other                                                   1767   7.306046
# Pakistani                                                787  15.337445
# Pancakes/Waffles                                         396  11.903154
# Peruvian                                                1814  13.684774
# Pizza                                                  24594  10.045228
# Pizza/Italian                                          10189  11.287882
# Polish                                                   686  10.594931
# Portuguese                                               245  14.552482
# Russian                                                 1884  10.946926
# Salads                                                   543   9.605490
# Sandwiches                                              6368   6.622560
# Sandwiches/Salads/Mixed Buffet                          2976   7.541548
# Scandinavian                                             144  10.879735
# Seafood                                                 3075  10.805709
# Soul Food                                                985  11.499184
# Soups & Sandwiches                                       567   6.051493
# Southwestern                                             194  11.216537
# Spanish                                                12499  13.654265
# Steak                                                   1711   9.428634
# Tapas                                                    544  11.391200
# Tex-Mex                                                 2708  10.415812
# Thai                                                    6640  12.971096
# Turkish                                                 1467  12.055186
# Vegetarian                                              1901  10.636047
# Vietnamese/Cambodian/Malaysia                           1780  13.228407
#
# [75 rows x 2 columns]

# %%
cuisavg_100 = cuisavg_100.drop(columns=['COUNT(*)'])

# %%
cuisavg_100 = cuisavg_100.sort_values(by=['AVG'])
cuisavg_100
# Out:
#                                                           AVG
# CODEDESC
# Hotdogs/Pretzels                                     4.355875
# Donuts                                               5.955119
# Soups & Sandwiches                                   6.051493
# Ice Cream, Gelato, Yogurt, Ices                      6.186705
# Sandwiches                                           6.622560
# Café/Coffee/Tea                                      6.711127
# Not Listed/Not Applicable                            6.823677
# Hotdogs                                              6.945130
# Bottled beverages, including water, sodas, juic...   7.072222
# Juice, Smoothies, Fruit Salads                       7.096782
# Other                                                7.306046
# Hamburgers                                           7.422499
# Sandwiches/Salads/Mixed Buffet                       7.541548
# Ethiopian                                            9.045143
# Barbecue                                             9.092645
# English                                              9.415152
# Steak                                                9.428634
# Cajun                                                9.533582
# Salads                                               9.605490
# American                                             9.646183
# Egyptian                                             9.846837
# Irish                                                9.922441
# Chicken                                              9.976872
# Pizza                                               10.045228
# Czech                                               10.054398
# Bagels/Pretzels                                     10.355715
# Continental                                         10.372899
# French                                              10.388353
# Tex-Mex                                             10.415812
# Middle Eastern                                      10.429903
# ...                                                       ...
# Jewish/Kosher                                       11.472467
# Soul Food                                           11.499184
# Australian                                          11.698074
# Brazilian                                           11.866598
# Pancakes/Waffles                                    11.903154
# Turkish                                             12.055186
# Mexican                                             12.079827
# Eastern European                                    12.233213
# Caribbean                                           12.301114
# Japanese                                            12.532185
# Delicatessen                                        12.576555
# Afghan                                              12.824952
# Thai                                                12.971096
# Latin (Cuban, Dominican, Puerto Rican, South & ...  13.144333
# Vietnamese/Cambodian/Malaysia                       13.228407
# Filipino                                            13.386791
# Indian                                              13.420129
# Korean                                              13.560305
# Spanish                                             13.654265
# Chinese                                             13.684387
# Peruvian                                            13.684774
# African                                             13.705349
# Asian                                               14.216914
# Portuguese                                          14.552482
# Chinese/Cuban                                       14.862191
# Indonesian                                          14.883495
# Bangladeshi                                         15.207520
# Pakistani                                           15.337445
# Chinese/Japanese                                    15.491931
# Creole                                              16.445931
#
# [75 rows x 1 columns]

# %%
cuisavg_100['AVG'] = cuisavg_100['AVG'].astype(str)
cuisavg_100
# Out:
#                                                                    AVG
# CODEDESC
# Hotdogs/Pretzels                                     4.355875152998776
# Donuts                                                5.95511894311671
# Soups & Sandwiches                                   6.051492733705664
# Ice Cream, Gelato, Yogurt, Ices                      6.186704891799307
# Sandwiches                                           6.622559679309581
# Café/Coffee/Tea                                      6.711126821420121
# Not Listed/Not Applicable                             6.82367709069637
# Hotdogs                                             6.9451302571088025
# Bottled beverages, including water, sodas, juic...   7.072222222222222
# Juice, Smoothies, Fruit Salads                       7.096782302162014
# Other                                                7.306046499304192
# Hamburgers                                           7.422499139941134
# Sandwiches/Salads/Mixed Buffet                       7.541547807978372
# Ethiopian                                             9.04514340178494
# Barbecue                                             9.092644525144934
# English                                              9.415152498377676
# Steak                                                9.428633975481612
# Cajun                                                 9.53358208955224
# Salads                                               9.605489948515423
# American                                             9.646183113549947
# Egyptian                                               9.8468366547733
# Irish                                                9.922440542130678
# Chicken                                              9.976871796735454
# Pizza                                                10.04522821887129
# Czech                                               10.054398148148149
# Bagels/Pretzels                                     10.355715297885402
# Continental                                         10.372899271629064
# French                                              10.388352543426903
# Tex-Mex                                              10.41581153259629
# Middle Eastern                                      10.429902540760306
# ...                                                                ...
# Jewish/Kosher                                       11.472466652059401
# Soul Food                                           11.499183556662851
# Australian                                          11.698074277854195
# Brazilian                                           11.866597831485706
# Pancakes/Waffles                                     11.90315408054023
# Turkish                                             12.055185750149631
# Mexican                                             12.079826753732489
# Eastern European                                     12.23321308041429
# Caribbean                                           12.301113904330045
# Japanese                                             12.53218536460661
# Delicatessen                                        12.576555065618628
# Afghan                                              12.824952259707192
# Thai                                                12.971095698175688
# Latin (Cuban, Dominican, Puerto Rican, South & ...    13.1443334643669
# Vietnamese/Cambodian/Malaysia                       13.228407378751475
# Filipino                                            13.386791176072538
# Indian                                              13.420129477455816
# Korean                                              13.560304647278368
# Spanish                                             13.654264615678944
# Chinese                                              13.68438655361727
# Peruvian                                            13.684774434085043
# African                                              13.70534874316242
# Asian                                               14.216914428000473
# Portuguese                                          14.552481692432872
# Chinese/Cuban                                       14.862191491404975
# Indonesian                                          14.883495145631068
# Bangladeshi                                         15.207519922982295
# Pakistani                                           15.337444604623846
# Chinese/Japanese                                    15.491931418834973
# Creole                                               16.44593118514473
#
# [75 rows x 1 columns]

# %%
def score_by_cuisine():
    return cuisavg_100
#[("French", 20.3550686378036)] * 75

grader.score('sql__score_by_cuisine', score_by_cuisine)
# Out:
# ['4.355875152998776'] is too short
#
# Failed validating 'minItems' in schema['items']:
#     {'items': [{'type': 'string'}, {'type': 'number'}],
#      'maxItems': 2,
#      'minItems': 2,
#      'type': 'array'}
#
# On instance[0]:
#     ['4.355875152998776']

# %% [markdown]
# ## Question 6: Specific violations by cuisine

# %% [markdown]
# Which cuisines tend to have a disproportionate number of what which violations? Answering this question isn't easy because you have to think carefully about normalizations.
#
# 1. More popular cuisine categories will tend to have more violations just because they represent more restaurants.
# 2. Similarly, some violations are more common.  For example, knowing that "Equipment not easily movable or sealed to floor" is a common violation for Chinese restaurants is not particularly helpful when it is a common violation for all restaurants.
#
# The right quantity is to look at is the conditional probability of a specific type of violation given a specific cuisine type and divide it by the unconditional probability of the violation for the entire population. Taking this ratio gives the right answer.  Return the 20 highest ratios of the form:
#
#     ((cuisine, violation), ratio, count)
#
# **Hint:**
# 1. You might want to check out this [Stack Overflow post](http://stackoverflow.com/questions/972877/calculate-frequency-using-sql).
# 2. The definition of a violation changes with time.  For example, 10A can mean two different things "Toilet facility not maintained ..." or "Vermin or other live animal present ..." when things were prior to 2003. To deal with this, you should limit your analysis to violation codes with end date after Jan 1, 2014. (This end date refers to the validity time ranges in `Violation.txt`).
# 3. The ratios don't mean much when the number of violations of a given type and for a specific category are not large (why not?).  Be sure to filter these out.  We chose 100 as our cutoff.
#
# **Checkpoint:**
# - Top 20 ratios mean: 2.360652529900757

# %%
# %%sql
# DROP TABLE IF EXISTS viol_cuisines;
# CREATE TABLE IF NOT EXISTS viol_cuisines AS
#     SELECT CAMIS, CUISINECODE, VIOLCODE, GRADEDATE
#     FROM webextract
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM viol_cuisines
# LIMIT 5;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [(30075445, 8, '10F', '2014-03-03 00:00:00'),
#  (30112340, 39, '06A', '2014-07-01 00:00:00'),
#  (30191841, 3, '10B', '2013-07-22 00:00:00'),
#  (40356483, 27, '08C', '2014-05-29 00:00:00'),
#  (30191841, 3, '02G', '2013-07-22 00:00:00')]

# %%
# %%sql
# DROP TABLE IF EXISTS violcode;
# CREATE TABLE IF NOT EXISTS violcode AS
#     SELECT *
#     FROM violations
#     GROUP BY VIOLATIONCODE
#     HAVING ENDDATE > '2014-01-01'
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM violcode
# LIMIT 5;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [(39, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02A', 'Food not cooked to required minimum temperature.'),
#  (46, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02B', 'Hot food item not held at or above 140º F.'),
#  (53, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02C', 'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65º F or above within 2 hours.'),
#  (60, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02D', 'Precooked potentially hazardous food from commercial food processing establishment that is supposed to be heated, but is not heated to 140º F within 2 hours.'),
#  (67, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02E', 'Whole frozen poultry or poultry breasts, other than a single portion, is being cooked frozen or partially thawed.')]

# %%
# %%sql
# DROP TABLE IF EXISTS violcode2;
# CREATE TABLE IF NOT EXISTS violcode2 AS
#     SELECT * FROM violcode
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM violcode2
# LIMIT 5;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [(39, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02A', 'Food not cooked to required minimum temperature.'),
#  (46, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02B', 'Hot food item not held at or above 140º F.'),
#  (53, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02C', 'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65º F or above within 2 hours.'),
#  (60, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02D', 'Precooked potentially hazardous food from commercial food processing establishment that is supposed to be heated, but is not heated to 140º F within 2 hours.'),
#  (67, '2010-07-26 00:00:00', '2099-12-31 00:00:00', 'Y', '02E', 'Whole frozen poultry or poultry breasts, other than a single portion, is being cooked frozen or partially thawed.')]

# %%
# %%sql
# DROP TABLE IF EXISTS viol_cuisines2;
# CREATE TABLE IF NOT EXISTS viol_cuisines2 AS
#     SELECT viol_cuisines.CAMIS, cuisine.CODEDESC, viol_cuisines.VIOLCODE
#     FROM viol_cuisines
#     LEFT JOIN cuisine ON viol_cuisines.CUISINECODE=cuisine.CUISINECODE;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM viol_cuisines2
# LIMIT 5;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [(30075445, 'Bakery', '10F'),
#  (30112340, 'Hamburgers', '06A'),
#  (30191841, 'American ', '10B'),
#  (40356483, 'Delicatessen', '08C'),
#  (30191841, 'American ', '02G')]

# %%
# %%sql
# DROP TABLE IF EXISTS viol_cuisines3;
# CREATE TABLE IF NOT EXISTS viol_cuisines3 AS
#     SELECT viol_cuisines2.CAMIS, viol_cuisines2.CODEDESC, viol_cuisines2.VIOLCODE, violcode2.VIOLATIONDESC
#     FROM viol_cuisines2
#     LEFT JOIN violcode2 ON viol_cuisines2.VIOLCODE=violcode2.VIOLATIONCODE;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM viol_cuisines3
# LIMIT 5;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [(30075445, 'Bakery', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.'),
#  (30112340, 'Hamburgers', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.'),
#  (30191841, 'American ', '10B', 'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.'),
#  (40356483, 'Delicatessen', '08C', 'Pesticide use not in accordance with label or applicable laws. Prohibited chemical used/stored. Open bait station used.'),
#  (30191841, 'American ', '02G', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.')]

# %%
# %%sql
# DROP TABLE IF EXISTS viol_cuisines4;
# CREATE TABLE IF NOT EXISTS viol_cuisines4 AS
#     SELECT CODEDESC, VIOLCODE, VIOLATIONDESC, COUNT(*)
#         FROM viol_cuisines3
#         GROUP BY CODEDESC, VIOLCODE, VIOLATIONDESC
#         HAVING COUNT(VIOLCODE) > 100;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# (sqlite3.OperationalError) misuse of aggregate function COUNT() [SQL: 'CREATE TABLE IF NOT EXISTS viol_cuisines4 AS\n    SELECT CODEDESC, VIOLCODE, VIOLATIONDESC\n        FROM viol_cuisines3\n    WHERE COUNT(VIOLCODE) > 100;'] (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# %%sql
# DROP TABLE IF EXISTS viol_freq;
# CREATE TABLE IF NOT EXISTS viol_freq AS
#     SELECT  A.CODEDESC, A.VIOLCODE, A.COUNT1 * 1.0 / B.COUNT2 AS FREQ
#     FROM    (
#             SELECT CODEDESC, VIOLCODE, COUNT(*) As COUNT1
#             FROM viol_cuisines3
#             GROUP BY CODEDESC, VIOLCODE
#             ) AS A
#             INNER JOIN (
#                 SELECT CODEDESC, COUNT(*) As COUNT2
#                 FROM viol_cuisines3
#                 GROUP BY CODEDESC
#                 ) As B
#                 On A.CODEDESC = B.CODEDESC
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM viol_freq
# LIMIT 5;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [('Afghan', None, 0.0036231884057971015),
#  ('Afghan', '02B', 0.014492753623188406),
#  ('Afghan', '02G', 0.043478260869565216),
#  ('Afghan', '02H', 0.0036231884057971015),
#  ('Afghan', '04A', 0.021739130434782608)]

# %%
# %%sql
# DROP TABLE IF EXISTS viol_freq2;
# CREATE TABLE IF NOT EXISTS viol_freq2 AS
#     SELECT viol_freq.CODEDESC, violcode2.VIOLATIONDESC, viol_freq.FREQ
#     FROM viol_freq
#     LEFT JOIN violcode2 ON viol_freq.VIOLCODE=violcode2.VIOLATIONCODE;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM viol_freq2
# LIMIT 5;
# Out:
#  * sqlite:///nyc_inspection.db
# Done.
# [('Afghan', None, 0.0036231884057971015),
#  ('Afghan', 'Hot food item not held at or above 140º F.', 0.014492753623188406),
#  ('Afghan', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.', 0.043478260869565216),
#  ('Afghan', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', 0.0036231884057971015),
#  ('Afghan', 'Food Protection Certificate not held by supervisor of food operations.', 0.021739130434782608)]

# %%
def violation_by_cuisine():
    return [(("Café/Coffee/Tea",
              "Toilet facility not maintained and provided with toilet paper; "
              "waste receptacle and self-closing door."),
             1.87684775827172, 315)] * 20

grader.score('sql__violation_by_cuisine', violation_by_cuisine)

# %% [markdown]
# *Copyright &copy; 2016 The Data Incubator.  All rights reserved.*
